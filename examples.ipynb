# %%
from src.utils import grainPreprocess, grainShow, grainMark, grainDraw, grainApprox, grainStats, grainMorphology,grainGenerate
from src.cfg import CfgAnglesNames, CfgBeamsNames, CfgDataset
from matplotlib import pyplot as plt

# %%
names=CfgDataset.images_names
print(names)
images=grainPreprocess.get_example_images()

plt.figure(figsize=(10,10))
plt.imshow(images[2,0],cmap='gray')
plt.show()
# Out:
# [['Ultra_Co8.jpg']
#  ['Ultra_Co11.jpg']
#  ['Ultra_Co6_2.jpg']
#  ['Ultra_Co15.jpg']
#  ['Ultra_Co25.jpg']]
# [2021-12-28 20:53:32,430: WARNING] downloading https://pobedit.s3.us-east-2.amazonaws.com/default_images/Ultra_Co8.jpg
# [2021-12-28 20:53:34,915: WARNING] downloading https://pobedit.s3.us-east-2.amazonaws.com/default_images/Ultra_Co11.jpg
# [2021-12-28 20:53:36,971: WARNING] downloading https://pobedit.s3.us-east-2.amazonaws.com/default_images/Ultra_Co6_2.jpg
# [2021-12-28 20:53:39,793: WARNING] downloading https://pobedit.s3.us-east-2.amazonaws.com/default_images/Ultra_Co15.jpg
# [2021-12-28 20:53:42,471: WARNING] downloading https://pobedit.s3.us-east-2.amazonaws.com/default_images/Ultra_Co25.jpg
