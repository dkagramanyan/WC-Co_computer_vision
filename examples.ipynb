# %%
import numpy as np

from src.utils import grainPreprocess, grainShow, grainMark, grainDraw, grainApprox, grainStats, grainMorphology,grainGenerate
from src.cfg import CfgAnglesNames, CfgBeamsNames, CfgDataset
from matplotlib import pyplot as plt

# %% [markdown]
# ## Downloading samples

# %%
names=CfgDataset.images_names
# print(names)
images=grainPreprocess.get_example_images()
# Out:
# [2022-05-26 20:54:29,215: WARNING] downloading https://pobedit.s3.us-east-2.amazonaws.com/default_images/Ultra_Co8.jpg
# [2022-05-26 20:54:31,569: WARNING] downloading https://pobedit.s3.us-east-2.amazonaws.com/default_images/Ultra_Co11.jpg
# [2022-05-26 20:54:36,251: WARNING] downloading https://pobedit.s3.us-east-2.amazonaws.com/default_images/Ultra_Co6_2.jpg
# [2022-05-26 20:54:38,312: WARNING] downloading https://pobedit.s3.us-east-2.amazonaws.com/default_images/Ultra_Co15.jpg
# [2022-05-26 20:54:40,684: WARNING] downloading https://pobedit.s3.us-east-2.amazonaws.com/default_images/Ultra_Co25.jpg

# %%
plt.figure(figsize=(10,10))
plt.imshow(images[2],cmap='gray')
plt.show()

# %%
img_cropped=grainPreprocess.imdivide(images[0],135,'left')
img=grainPreprocess.image_preprocess(img_cropped)
grainShow.img_show(img,N=8,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-67b225544753> in <module>
# ----> 1 img=grainPreprocess.image_preprocess(img_cropped)
#       2 grainShow.img_show(img,N=8,cmap='gray')
#
# D:\PROJECTS\python\grain_segmentation\src\utils.py in image_preprocess(cls, image)
#     123         """
#     124         :param img: ndarray (height,width,channels)
# --> 125         :return: ndarray (height,width), Boolean
#     126         """
#     127         #
#
# D:\PROJECTS\python\grain_segmentation\src\utils.py in do_otsu(cls, img)
#     104         :param k: float scalar
#     105         :return: ndarray (height,width/2,channels)
# --> 106         """
#     107         #
#     108         #  накладывает левую и правые части изображения
#
# ~\AppData\Roaming\Python\Python38\site-packages\skimage\filters\thresholding.py in threshold_otsu(image, nbins, hist)
#     328     if image is not None:
#     329         first_pixel = image.ravel()[0]
# --> 330         if np.all(image == first_pixel):
#     331             return first_pixel
#     332
#
# KeyboardInterrupt:

# %%
grainShow.img_show(img,N=8,cmap='gray')

# %%
img_cropped=grainPreprocess.imdivide(images[0],135,'left')
